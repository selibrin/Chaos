# %% [markdown]
# <h3> Построить сечения Пуанкаре следующих динамических систем для нескольких значений параметров из указанных интервалов. В отчете привести несколько сечений Пуанкаре для различных величин параметров, соответствующие им фазовые портреты и предположить возможный сценарий перехода к хаосу.  </h3>

# %% [markdown]
# <span style="font-style:normal; font-size:10pt;">
#
# \begin{equation}
# \dddot{x} + \ddot{x} + s\dot{x} - rx + x^2 = 0
# \end{equation}
#
# <text> Зафиксировать </text>
#
# \begin{equation}
# s = 0.5,\
# r ∈ [0.75, \ 0.95]
# \end{equation}

# %% [markdown]
# <h4> Сведем дифференциальное уравнение к каноническому виду: </h4>
# \begin{cases}
# \dot{x} = x_{1} \\
# \dot{x_{1}} = x_{2}\\
# \dot{x_{2}} = -x_{2} - sx_{1} + rx - x^2 = F(x,x_{1},x_{2})
# \end{cases}

# %% [markdown]
# ### Сечения Пуанкаре и фазовые портреты

# %% [markdown]
# <h3> Начальные значения \begin{equation}
# \dot x = 0.1\\
# \dot x_{1}=0.1\\
# \dot x_{2}=0.1
# \end{equation}
# </h3>
# <h3> Время \begin{equation}
# t = 1000\\
# dt=0.01
# \end{equation}
# </h3>

# %% [markdown]
# #### Для r=0.75

# %% [markdown]
# ![2022-05-20_20-46-32.png](data:image/png;base64,...)![newplot.png](data:image/png;base64,...)![2022-05-20_20-48-41.png](data:image/png;base64,...)

# %% [markdown]
# #### Для r=0.8

# %% [markdown]
# ![2022-05-20_20-52-46.png](data:image/png;base64,...)![newplot (1).png](data:image/png;base64,...)![2022-05-20_20-51-39.png](data:image/png;base64,...)

# %% [markdown]
# #### Для r=0.85

# %% [markdown]
# ![2022-05-20_21-03-46.png](data:image/png;base64,...)![newplot (2).png](data:image/png;base64,...)![2022-05-20_21-04-30.png](data:image/png;base64,...)

# %% [markdown]
# #### Для r=0.9

# %% [markdown]
# ![2022-05-20_21-17-27.png](data:image/png;base64,...)![newplot (3).png](data:image/png;base64,...)![2022-05-20_21-18-11.png](data:image/png;base64,...)

# %% [markdown]
# #### Для r=0.95

# %% [markdown]
# ![2022-05-20_21-20-38.png](data:image/png;base64,...)![newplot (4).png](data:image/png;base64,...)![2022-05-20_21-21-23.png](data:image/png;base64,...)

# %% [markdown]
# ### Сценарий перехода к хаосу

# %% [markdown]
# #### Если r ∈ [0.75, 0.95]. Шаг по параметру = 0.1

# %% [markdown]
# ![newplot (6).png](data:image/png;base64,...)

# %% [markdown]
# #### Для r ∈ [-25, 25]. Шаг по r = 0.1

# %% [markdown]
# ![newplot (5).png](data:image/png;base64,...)

# %% [markdown]
# <text> Зум </text>

# %% [markdown]
# ![newplot (8).png](data:image/png;base64,...)
